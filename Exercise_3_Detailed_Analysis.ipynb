# %% [markdown]
# # Exercise 3: Advanced Data Visualization - Formal Academic Charts
#
# **Objective:** Create professional, publication-quality visualizations for academic and formal presentations
#
# **Time:** 45-60 minutes
#
# **Skills You'll Practice:**
# - Loading and cleaning complex datasets
# - Data resampling and aggregation
# - Creating dual y-axis plots (advanced)
# - Creating grouped bar charts (advanced)
# - Advanced plot customization for formal presentations
# - Multiple visualizations in one exercise
#
# ---
#
# ## ⚠️ Important Note for Beginners
#
# This exercise is **more advanced** than Exercises 1 and 2. It introduces complex concepts like:
# - Data resampling (changing time intervals)
# - Dual y-axis plots (two different scales)
# - Grouped bar charts with manual positioning
# - Advanced formatting for academic papers
#
# **Don't worry if it seems challenging!** Follow along step-by-step, and you'll learn these advanced techniques. The goal is to create **formal, publication-quality charts** that you can use in reports, papers, and presentations.
#
# ---

# %% [markdown]
# ## Part 1: Setup and Import Libraries
#
# **What libraries do we need?**
#
# - **pandas** (`pd`) - Data manipulation
# - **matplotlib.pyplot** (`plt`) - Basic plotting
# - **seaborn** (`sns`) - Beautiful statistical visualizations and themes
# - **matplotlib.dates** (`mdates`) - Advanced date formatting
# - **numpy** (`np`) - Numerical operations (for array manipulation)
# - **os** - File system operations (creating folders)
#
# **Why so many libraries?**
# - Each library has specialized tools
# - Seaborn provides beautiful themes for academic papers
# - matplotlib.dates helps format dates nicely
# - numpy helps with array operations for grouped bars
#
# **Your Task:** Import all required libraries

# %%
# Part 1: Import all required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates
import numpy as np
import os

# Register pandas datetime converters for matplotlib
# This helps matplotlib understand pandas datetime objects
pd.plotting.register_matplotlib_converters()

# Set seaborn theme for academic/formal styling
# 'whitegrid' = white background with grid lines
# 'Times New Roman' = formal academic font
# font_scale=2 = larger fonts for readability
sns.set_theme(style="whitegrid", font="Times New Roman", font_scale=2)

# Create a 'plots' folder to save our charts
# exist_ok=True means: create if it doesn't exist, don't error if it does
os.makedirs('plots', exist_ok=True)

print("✅ Setup Complete - All libraries loaded and configured!")

# %% [markdown]
# ---
#
# ## Part 2: Load and Clean the Data
#
# **What are we loading?**
# - Office sensor data with environmental measurements
# - Contains temperature, humidity, air quality (PM2.5, PM10), etc.
# - Data is recorded at regular intervals (time series data)
#
# **Why do we need special parameters?**
# - `encoding='ISO-8859-1'` - Handles special characters in the file
# - `index_col="Datetime"` - Uses the Datetime column as the index (row labels)
# - `parse_dates=True` - Converts date strings to actual date objects
# - `dayfirst=True` - Dates are in DD.MM.YYYY format (European format)
#
# **What is an index?**
# - The index is like row numbers, but instead of 0, 1, 2..., we use dates
# - This makes it easier to work with time series data
#
# **Your Task:** Load the office sensor data

# %%
# Part 2: Load the office sensor data
filepath = "dataset/May_Office_213.csv"

# Load CSV with encoding fix and parse dates
df = pd.read_csv(
    filepath,
    encoding='ISO-8859-1',  # Handles special characters
    index_col="Datetime",    # Use Datetime column as index
    parse_dates=True,         # Convert dates to datetime objects
    dayfirst=True             # Dates are in DD.MM.YYYY format
)

# Clean up column names
# Remove spaces and replace special characters with underscores
# This makes column names easier to work with
# Example: 'Temperature (°C)' becomes 'Temperature_C_'
df.columns = df.columns.str.strip().str.replace('[^A-Za-z0-9_]+', '_', regex=True)

# Sort by datetime index (important for time series)
df = df.sort_index()

# Display information about the loaded data
print("✅ Data loaded successfully!")
print(f"First date in data: {df.index.min()}")
print(f"Last date in data: {df.index.max()}")
print(f"\nNumber of rows: {len(df)}")
print(f"Number of columns: {len(df.columns)}")
print("\nColumn names:")
print(df.columns.tolist())
print("\nFirst few rows:")
df.head()

# %% [markdown]
# **Understanding the data:**
# - Each row represents one measurement at a specific time
# - Columns represent different measurements (temperature, humidity, etc.)
# - The index (Datetime) tells us WHEN each measurement was taken
#
# **Why clean column names?**
# - Original names might have spaces or special characters
# - Clean names are easier to type and reference
# - Example: `df['Temperature_C_']` is easier than `df['Temperature (°C)']`

# %% [markdown]
# ---
#
# ## Part 3: Data Resampling - Understanding Time Intervals
#
# **What is resampling?**
# - Our data might be recorded every hour or every few minutes
# - For visualization, we often want daily averages instead
# - **Resampling** means changing the time interval of our data
#
# **Why resample?**
# - Too much data points = cluttered, hard-to-read charts
# - Daily averages = cleaner, easier to understand trends
# - Better for formal presentations and reports
#
# **How does it work?**
# - `resample('D')` = Group data by Day
# - `.mean()` = Calculate the average for each day
# - Result: One value per day (the average of all measurements that day)
#
# **Example:**
# - Original: 24 measurements per day (hourly)
# - After resampling: 1 value per day (daily average)
#
# **Your Task:** Resample the data to daily averages

# %%
# Part 3: Resample data to daily averages

# First, select only numeric columns (we can't average text!)
# select_dtypes(include='number') gets only columns with numbers
numeric_df = df.select_dtypes(include='number')

print("Numeric columns selected:")
print(numeric_df.columns.tolist())
print(f"\nOriginal data shape: {df.shape}")
print(f"Numeric data shape: {numeric_df.shape}")

# Resample to daily averages
# 'D' = Day, .mean() = calculate average, .round(2) = round to 2 decimals
daily_selected = numeric_df.resample('D').mean().round(2)

print(f"\nAfter resampling to daily averages:")
print(f"Daily data shape: {daily_selected.shape}")
print("\nFirst few days of daily averages:")
print(daily_selected.head())
print("\n✅ Data resampled successfully!")

# %% [markdown]
# **What happened?**
# - We selected only numeric columns (temperature, humidity, PM values, etc.)
# - Resampled from original frequency (maybe hourly) to daily
# - Calculated the mean (average) for each day
# - Rounded to 2 decimal places for readability
#
# **Result:** Clean daily data ready for visualization!
#
# **Other resampling options:**
# - `'H'` = Hourly
# - `'D'` = Daily
# - `'W'` = Weekly
# - `'M'` = Monthly

# %% [markdown]
# ---
#
# ## Part 4: Visualization 1 - Dual Y-Axis Plot (Advanced)
#
# **What is a dual y-axis plot?**
# - A chart with **two different y-axes** (left and right)
# - Each axis has its own scale and units
# - Allows comparing two variables with different units on the same chart
#
# **Why use dual y-axis?**
# - Compare variables with different scales (e.g., temperature in °C vs humidity in %)
# - Show relationships between different measurements
# - Common in scientific and academic papers
#
# **Example:**
# - Left axis: Humidity (0-100%)
# - Right axis: Temperature (0-40°C)
# - Both plotted on the same chart!
#
# **How it works:**
# 1. Create first axis (ax1) and plot first variable
# 2. Create second axis (ax2) using `twinx()` - shares x-axis with ax1
# 3. Plot second variable on ax2
# 4. Customize both axes separately
#
# **Your Task:** Create a dual y-axis plot showing Humidity and Temperature

# %%
# Part 4: Create dual y-axis plot

# Create figure and first axis
# figsize=(18, 9) = large size for formal presentations
fig, ax1 = plt.subplots(figsize=(18, 9))

# ===== LEFT Y-AXIS: Relative Humidity =====
# Get color from seaborn's color palette (professional colors)
color1 = sns.color_palette("deep")[0]  # Blue color

# Plot humidity on left axis
# l1, = means we're storing the line object (needed for legend)
l1, = ax1.plot(
    daily_selected.index,              # X-axis: dates
    daily_selected['Humidity_'],       # Y-axis: humidity values
    color=color1,                      # Line color
    linestyle='-',                     # Solid line
    linewidth=3,                       # Thick line (3 points)
    marker='o',                         # Circle markers
    markersize=8,                       # Marker size
    label='Relative Humidity [%]'      # Label for legend
)

# Customize left y-axis
ax1.set_ylabel('Relative Humidity [%]', color='k', fontsize=32, weight='bold')
ax1.tick_params(axis='y', labelcolor='k')  # Y-axis label color
ax1.set_ylim([0, 100])                      # Y-axis range: 0 to 100%
ax1.set_yticks([0, 25, 50, 75, 100])        # Y-axis tick marks

# ===== RIGHT Y-AXIS: Temperature =====
# Create second axis sharing the same x-axis
ax2 = ax1.twinx()  # 'twinx' = twin x-axis (shares x, new y)

# Get different color for temperature
color2 = sns.color_palette("deep")[1]  # Orange color

# Plot temperature on right axis
l2, = ax2.plot(
    daily_selected.index,
    daily_selected['Temperature_C_'],
    color=color2,
    linestyle='-',
    linewidth=3,
    marker='s',                         # Square markers (different from humidity)
    markersize=8,
    label='Indoor Temperature [°C]'
)

# Customize right y-axis
ax2.set_ylabel('Indoor Temperature [°C]', color='k', fontsize=32, weight='bold')
ax2.tick_params(axis='y', labelcolor='k')
ax2.set_ylim([0, 40])  # Temperature range: 0 to 40°C

# ===== X-AXIS: Format dates nicely =====
# Show dates every 2 days (not too crowded)
ax1.xaxis.set_major_locator(mdates.DayLocator(interval=2))
# Format dates as 'DD-Month' (e.g., '01-May')
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%d-%b'))
# Rotate dates 45 degrees for readability
fig.autofmt_xdate(rotation=45)

# ===== FINAL TOUCHES =====
# Add grid
ax1.grid(True, which='major', axis='both', linestyle='--', alpha=0.5)

# Create legend combining both lines
lines = [l1, l2]
labels = [line.get_label() for line in lines]
ax1.legend(lines, labels, loc='upper right', fontsize=19, frameon=False, fancybox=True, shadow=True)

# Add title
plt.title('Humidity and Temperature Over Time', fontsize=36, weight='bold', pad=20)

# Adjust layout to prevent label cutoff
plt.tight_layout()

# Save as high-quality image for formal use
plt.savefig('plots/Office213_HumTemp_May2025.jpg', format='jpg', dpi=150)

# Display the plot
plt.show()

print("✅ Dual y-axis plot created and saved!")

# %% [markdown]
# **Understanding the code step by step:**
#
# 1. **Create figure and first axis:** `fig, ax1 = plt.subplots()`
#    - `fig` = the entire figure (canvas)
#    - `ax1` = the first axis (left y-axis)
#
# 2. **Plot first variable:** Plot humidity on `ax1`
#    - Store the line object in `l1` (needed for legend)
#
# 3. **Create second axis:** `ax2 = ax1.twinx()`
#    - `twinx()` creates a new y-axis sharing the same x-axis
#    - Now we have two y-axes!
#
# 4. **Plot second variable:** Plot temperature on `ax2`
#    - Different color and marker to distinguish from humidity
#
# 5. **Customize both axes:** Set labels, limits, colors separately
#
# 6. **Format dates:** Use matplotlib.dates to show dates nicely
#
# 7. **Add legend:** Combine both lines in one legend
#
# **Result:** Professional dual-axis chart ready for academic papers!

# %% [markdown]
# ---
#
# ## Part 5: Visualization 2 - Grouped Bar Chart (Advanced)
#
# **What is a grouped bar chart?**
# - Multiple bars grouped together for each category
# - Each group has bars for different variables
# - Allows comparing multiple variables side-by-side
#
# **Example:**
# - Each date has TWO bars side-by-side
# - One bar for PM2.5, one bar for PM10
# - Easy to compare both values for each day
#
# **Why grouped bars?**
# - Compare multiple variables across categories
# - Show relationships clearly
# - Professional appearance for reports
#
# **How it works:**
# 1. Create positions for bars using `np.arange()`
# 2. Calculate bar width
# 3. Position first set of bars: `x - bar_width/2`
# 4. Position second set of bars: `x + bar_width/2`
# 5. This creates side-by-side bars!
#
# **Your Task:** Create a grouped bar chart comparing PM2.5 and PM10

# %%
# Part 5: Create grouped bar chart

# Extract data for PM2.5 and PM10
pm25 = daily_selected['PM2_5_ug_m3_']  # PM2.5 values
pm10 = daily_selected['PM10_ug_m3_']    # PM10 values
dates = daily_selected.index            # Dates for x-axis

# Set bar width (how wide each bar is)
bar_width = 0.4  # 0.4 means bars take up 40% of the space

# Create positions for bars
# np.arange(len(dates)) creates [0, 1, 2, 3, ...] for each date
# This gives us x-positions for our bars
x = np.arange(len(dates))

# Create figure
fig, ax = plt.subplots(figsize=(18, 9))

# Choose distinct colors
color_pm25 = '#1f77b4'  # Blue
color_pm10 = '#ff7f0e'  # Orange

# ===== PM2.5 BARS (positioned to the left) =====
# x - bar_width/2 shifts bars to the left
# Example: if x=2 and bar_width=0.4, bars are at 2-0.2=1.8
bars1 = ax.bar(
    x - bar_width/2,    # X-positions (shifted left)
    pm25,                # Y-values (heights of bars)
    width=bar_width,     # Width of each bar
    label='PM2.5 (μg/m³)',
    color=color_pm25
)

# ===== PM10 BARS (positioned to the right) =====
# x + bar_width/2 shifts bars to the right
# Example: if x=2 and bar_width=0.4, bars are at 2+0.2=2.2
bars2 = ax.bar(
    x + bar_width/2,    # X-positions (shifted right)
    pm10,                # Y-values
    width=bar_width,
    label='PM10 (μg/m³)',
    color=color_pm10
)

# ===== CUSTOMIZE Y-AXIS =====
ax.set_ylim(0, 25)                    # Y-axis range: 0 to 25
ax.set_yticks(np.arange(0, 26, 5))   # Tick marks: 0, 5, 10, 15, 20, 25

# ===== CUSTOMIZE X-AXIS =====
# Show every 3rd date to avoid crowding
# [::3] means: start at 0, take every 3rd item
ax.set_xticks(x[::3])
# Format dates nicely
ax.set_xticklabels(
    [d.strftime('%d-%b') for d in dates[::3]],  # Format each date
    rotation=45,                                  # Rotate 45 degrees
    ha='right'                                    # Align to right
)

# ===== ADD LABELS AND TITLE =====
ax.set_ylabel('PM Concentration (μg/m³)', fontsize=32, weight='bold')
ax.set_xlabel('Date', fontsize=32, weight='bold')
ax.legend(fontsize=19, frameon=True, fancybox=True, shadow=True)
plt.title('Daily PM2.5 and PM10 Concentrations', fontsize=36, weight='bold', pad=20)

# ===== FINALIZE =====
plt.tight_layout()
plt.savefig('plots/Office213_PMs_May2025.jpg', format='jpg', dpi=150)
plt.show()

print("✅ Grouped bar chart created and saved!")

# %% [markdown]
# **Understanding the positioning:**
#
# **Why `x - bar_width/2` and `x + bar_width/2`?**
#
# Imagine dates are at positions: 0, 1, 2, 3...
#
# - **PM2.5 bars:** Positioned at `x - 0.2` (left of center)
#   - Date 0: bar at position -0.2
#   - Date 1: bar at position 0.8
#   - Date 2: bar at position 1.8
#
# - **PM10 bars:** Positioned at `x + 0.2` (right of center)
#   - Date 0: bar at position 0.2
#   - Date 1: bar at position 1.2
#   - Date 2: bar at position 2.2
#
# **Result:** Two bars side-by-side for each date!
#
# **Key concepts:**
# - `np.arange(len(dates))` creates array [0, 1, 2, 3, ...]
# - `x[::3]` means "every 3rd element" (slicing)
# - `d.strftime('%d-%b')` formats date as "01-May"
# - Bar width controls how close/far bars are

# %% [markdown]
# ---
#
# ## Part 6: Data Summary and Statistics
#
# **Why calculate statistics?**
# - Summarize your data numerically
# - Understand central tendencies (mean, median)
# - Understand variability (min, max, standard deviation)
# - Essential for academic reports
#
# **Common statistics:**
# - **Mean:** Average value
# - **Min:** Minimum value
# - **Max:** Maximum value
# - **Std:** Standard deviation (how spread out values are)
#
# **Your Task:** Calculate and display summary statistics

# %%
# Part 6: Calculate summary statistics

print("=== SUMMARY STATISTICS ===\n")

# Temperature statistics
if 'Temperature_C_' in daily_selected.columns:
    print("Temperature (°C):")
    print(f"  Mean: {daily_selected['Temperature_C_'].mean():.2f}")      # Average
    print(f"  Min:  {daily_selected['Temperature_C_'].min():.2f}")       # Minimum
    print(f"  Max:  {daily_selected['Temperature_C_'].max():.2f}")       # Maximum
    print(f"  Std:  {daily_selected['Temperature_C_'].std():.2f}")       # Standard deviation
    print()

# Humidity statistics
if 'Humidity_' in daily_selected.columns:
    print("Humidity (%):")
    print(f"  Mean: {daily_selected['Humidity_'].mean():.2f}")
    print(f"  Min:  {daily_selected['Humidity_'].min():.2f}")
    print(f"  Max:  {daily_selected['Humidity_'].max():.2f}")
    print(f"  Std:  {daily_selected['Humidity_'].std():.2f}")
    print()

# PM2.5 statistics
if 'PM2_5_ug_m3_' in daily_selected.columns:
    print("PM2.5 (μg/m³):")
    print(f"  Mean: {daily_selected['PM2_5_ug_m3_'].mean():.2f}")
    print(f"  Min:  {daily_selected['PM2_5_ug_m3_'].min():.2f}")
    print(f"  Max:  {daily_selected['PM2_5_ug_m3_'].max():.2f}")
    print()

# PM10 statistics
if 'PM10_ug_m3_' in daily_selected.columns:
    print("PM10 (μg/m³):")
    print(f"  Mean: {daily_selected['PM10_ug_m3_'].mean():.2f}")
    print(f"  Min:  {daily_selected['PM10_ug_m3_'].min():.2f}")
    print(f"  Max:  {daily_selected['PM10_ug_m3_'].max():.2f}")
    print()

print("✅ Statistics calculated!")

# %% [markdown]
# **Understanding the statistics:**
#
# - **Mean:** The average value - tells you the typical value
# - **Min/Max:** The range of values - shows variability
# - **Std (Standard Deviation):** How spread out values are
#   - Low std = values are close together
#   - High std = values are spread out
#
# **Why use `.2f`?**
# - Formats numbers to 2 decimal places
# - Makes output clean and readable
# - Example: `85.6789` becomes `85.68`

# %% [markdown]
# ---
#
# ## Part 7: Challenge - Create Your Own Visualization
#
# **Your Task:** Choose any two variables from the dataset and create a visualization
#
# **Suggestions:**
# - Compare any two environmental variables
# - Create a scatter plot showing correlation
# - Create a time series with multiple variables
# - Try creating another dual-axis plot
# - Be creative!
#
# **Tips:**
# - Use the code from Parts 4 and 5 as templates
# - Experiment with different chart types
# - Try different colors and styles
# - Remember to add labels, title, and save your plot!

# %%
# Part 7: Your own visualization
# Write your code here
# Choose variables and create a chart

# Example template:
# fig, ax = plt.subplots(figsize=(18, 9))
# ax.plot(daily_selected.index, daily_selected['Your_Column'], ...)
# ax.set_xlabel('...')
# ax.set_ylabel('...')
# plt.title('...')
# plt.tight_layout()
# plt.savefig('plots/Your_Chart.jpg', format='jpg', dpi=150)
# plt.show()

# %% [markdown]
# ---
#
# ## ✅ Exercise Complete!
#
# **Congratulations!** You've completed advanced data visualization! 🎉
#
# ### What You've Learned:
#
# ✅ **Advanced data loading** - Handling encoding, dates, and cleaning
# ✅ **Data resampling** - Changing time intervals (hourly → daily)
# ✅ **Dual y-axis plots** - Comparing variables with different scales
# ✅ **Grouped bar charts** - Comparing multiple variables side-by-side
# ✅ **Advanced customization** - Professional formatting for formal presentations
# ✅ **Summary statistics** - Calculating mean, min, max, standard deviation
#
# ### Key Advanced Concepts:
#
# **1. Data Resampling:**
# - `resample('D')` - Group by day
# - `.mean()` - Calculate average
# - Essential for time series analysis
#
# **2. Dual Y-Axis:**
# - `ax1.twinx()` - Create second y-axis
# - Plot different variables on each axis
# - Perfect for comparing different units
#
# **3. Grouped Bars:**
# - `np.arange()` - Create positions
# - Position bars with `x - width/2` and `x + width/2`
# - Side-by-side comparison
#
# **4. Formal Styling:**
# - Large fonts (fontsize=32, 36)
# - Professional colors
# - High resolution (dpi=150)
# - Clean formatting
#
# ### Tips for Formal Charts:
#
# 1. **Always add labels** - X-axis, Y-axis, title
# 2. **Use appropriate colors** - Professional, not too bright
# 3. **Large fonts** - Readable in presentations
# 4. **High resolution** - dpi=150 or higher for printing
# 5. **Clean layout** - Use `tight_layout()` to prevent cutoff
# 6. **Save your work** - Always save charts for later use
#
# ### Common Mistakes to Avoid:
#
# ❌ **Forgetting `twinx()`** - Can't create dual-axis without it
# ❌ **Wrong bar positioning** - Bars overlap if positioning is wrong
# ❌ **Missing labels** - Charts without labels are unprofessional
# ❌ **Low resolution** - Charts look blurry when printed
# ❌ **Crowded dates** - Show every 2-3 days, not all dates
#
# ### Next Steps:
#
# 1. Practice creating more visualizations
# 2. Experiment with different chart types
# 3. Try different color schemes
# 4. Create visualizations for your own data
# 5. Use these techniques in your reports and presentations
#
# ---
#
# **Excellent work! You now have the skills to create professional, publication-quality visualizations!** 🚀
